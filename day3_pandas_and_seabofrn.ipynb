# %% [markdown]
# pandas :'
# -used for data manipltion
# -craates data from one forem to another dorm (excel,csv,txt,dbs)
# -data frame(rows and colums readabel by python)
# -data cleaning by droping or replacing with mean
# -visual the data

# %%
import pandas as pd

# %%
names=["kusuma","teja","sada","kaveri","varsha","lory"]
index=[40,42,42,43,45,46]
ser1=pd.Series(names,index)
print(ser1)
# Out:
# 40    kusuma
# 42      teja
# 42      sada
# 43    kaveri
# 45    varsha
# 46      lory
# dtype: object

# %% [markdown]
# importing files
# -for cvsand txt:read_csv("file path")
# -for excel:read_exel("file path")

# %%
df=pd.read_csv("/content/diabetcsv.csv")

# %%
df.head(10)
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive
# 5     5   116    74     0     0  25.6  0.201   30  tested_negative
# 6     3    78    50    32    88  31.0  0.248   26  tested_positive
# 7    10   115     0     0     0  35.3  0.134   29  tested_negative
# 8     2   197    70    45   543  30.5  0.158   53  tested_positive
# 9     8   125    96     0     0   0.0  0.232   54  tested_positive

# %%
df.tail()
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative

# %%
df=pd.read_csv("/content/dummy_data.csv")

# %%
df.tail()
# Out:
#      age      gender  time_spent   platform  interests        location  \
# 995   22      female           8  Instagram  Lifestlye  United Kingdom
# 996   40  non-binary           6    YouTube     Travel  United Kingdom
# 997   27  non-binary           5    YouTube     Travel  United Kingdom
# 998   61      female           4    YouTube     Sports       Australia
# 999   19      female           8    YouTube     Travel       Australia
#
#     demographics         profession  income  indebt  isHomeOwner  Owns_Car
# 995        Rural   Marketer Manager   18536   False         True     False
# 996        Rural  Software Engineer   12711    True        False     False
# 997        Rural            Student   17595    True        False      True
# 998    Sub_Urban   Marketer Manager   16273    True         True     False
# 999        Rural            Student   16284   False         True     False

# %%
dft=pd.read_csv("/content/dummy_data [MConverter.eu].txt",sep=",")

# %%
dft.tail()
# Out:
#      age      gender  time_spent   platform  interests        location  \
# 995   22      female           8  Instagram  Lifestlye  United Kingdom
# 996   40  non-binary           6    YouTube     Travel  United Kingdom
# 997   27  non-binary           5    YouTube     Travel  United Kingdom
# 998   61      female           4    YouTube     Sports       Australia
# 999   19      female           8    YouTube     Travel       Australia
#
#     demographics         profession  income  indebt  isHomeOwner  Owns_Car
# 995        Rural   Marketer Manager   18536   False         True     False
# 996        Rural  Software Engineer   12711    True        False     False
# 997        Rural            Student   17595    True        False      True
# 998    Sub_Urban   Marketer Manager   16273    True         True     False
# 999        Rural            Student   16284   False         True     False

# %%
dfe=pd.read_excel("/content/dummy_data.xlsx")

# %%
dfe.head()
# Out:
#    age      gender  time_spent   platform  interests        location  \
# 0   56        male           3  Instagram     Sports  United Kingdom
# 1   46      female           2   Facebook     Travel  United Kingdom
# 2   32        male           8  Instagram     Sports       Australia
# 3   60  non-binary           5  Instagram     Travel  United Kingdom
# 4   25        male           1  Instagram  Lifestlye       Australia
#
#   demographics         profession  income  indebt  isHomeOwner  Owns_Car
# 0        Urban  Software Engineer   19774    True        False     False
# 1        Urban            Student   10564    True         True      True
# 2    Sub_Urban   Marketer Manager   13258   False        False     False
# 3        Urban            Student   12500   False         True     False
# 4        Urban  Software Engineer   14566   False         True      True

# %%
df=pd.read_csv("/content/dummy_data.csv")
print(df.describe)
# Out:
# <bound method NDFrame.describe of      age      gender  time_spent   platform  interests        location  \
# 0     56        male           3  Instagram     Sports  United Kingdom
# 1     46      female           2   Facebook     Travel  United Kingdom
# 2     32        male           8  Instagram     Sports       Australia
# 3     60  non-binary           5  Instagram     Travel  United Kingdom
# 4     25        male           1  Instagram  Lifestlye       Australia
# ..   ...         ...         ...        ...        ...             ...
# 995   22      female           8  Instagram  Lifestlye  United Kingdom
# 996   40  non-binary           6    YouTube     Travel  United Kingdom
# 997   27  non-binary           5    YouTube     Travel  United Kingdom
# 998   61      female           4    YouTube     Sports       Australia
# 999   19      female           8    YouTube     Travel       Australia
#
#     demographics         profession  income  indebt  isHomeOwner  Owns_Car
# ...

# %%
df=pd.read_csv("/content/dummy_data.csv")
print(df.shape)
print(df.shape[0])
print(df.shape[1])
# Out:
# (1000, 12)
# 1000
# 12

# %%
print(df.columns)
# Out:
# Index(['age', 'gender', 'time_spent', 'platform', 'interests', 'location',
#        'demographics', 'profession', 'income', 'indebt', 'isHomeOwner',
#        'Owns_Car'],
#       dtype='object')

# %% [markdown]
# acsseindg data
# loc-accepting columnnames and index
# iloc-accepts only index

# %%
dft.describe()
# Out:
#                age   time_spent        income
# count  1000.000000  1000.000000   1000.000000
# mean     40.986000     5.029000  15014.823000
# std      13.497852     2.537834   2958.628221
# min      18.000000     1.000000  10012.000000
# 25%      29.000000     3.000000  12402.250000
# 50%      42.000000     5.000000  14904.500000
# 75%      52.000000     7.000000  17674.250000
# max      64.000000     9.000000  19980.000000

# %%
print(dft[2:5])
# Out:
#    age      gender  time_spent   platform  interests        location  \
# 2   32        male           8  Instagram     Sports       Australia
# 3   60  non-binary           5  Instagram     Travel  United Kingdom
# 4   25        male           1  Instagram  Lifestlye       Australia
#
#   demographics         profession  income  indebt  isHomeOwner  Owns_Car
# 2    Sub_Urban   Marketer Manager   13258   False        False     False
# 3        Urban            Student   12500   False         True     False
# 4        Urban  Software Engineer   14566   False         True      True

# %%
print(dft.loc[2:5,["age"]])
# Out:
#    age
# 2   32
# 3   60
# 4   25
# 5   38

# %%
print(dft.iloc[2:5,:3])
# Out:
#    age      gender  time_spent
# 2   32        male           8
# 3   60  non-binary           5
# 4   25        male           1

# %%
dfn=pd.read_csv("/content/grades_withnulls.csv")

# %%
dfn.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1

# %%
dfn.isnull().head(7)
# Out:
#    Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0  False     False  False  False  False  False   False
# 1  False     False  False  False  False  False   False
# 2  False     False  False  False  False  False   False
# 3  False     False  False  False   True  False   False
# 4  False     False  False  False  False  False   False
# 5  False     False  False  False  False  False   False
# 6  False     False  False  False  False  False   False

# %%
dfn.isnull()
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
dfn.isnull().sum()
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
dfn.dropna()#drops all the null value
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfn.isnull().sum().sum()
# Out:
# 4

# %%
dfc=dfn.dropna()
print(dfc)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc1=dfn.fillna(5)
dfc1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   5.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   5.0   9.1   9.9    A+       1
# 9   Rajini        M   5.0   9.1   9.3     A       0
# 10   Kiran        V   5.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
m=dfn['SEM3'].mean()
print(m)
# Out:
# 9.100000000000001

# %%
dfc2=dfn.fillna(m)
print(dfc2)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.1     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.1   9.1   9.9    A+       1
# 9   Rajini        M   9.1   9.1   9.3     A       0
# 10   Kiran        V   9.1   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
drope=dfc2.drop_duplicates()
print(drope)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.1     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.1   9.1   9.9    A+       1
# 9   Rajini        M   9.1   9.1   9.3     A       0
# 10   Kiran        V   9.1   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfn.rename(columns={"Grade":"gpa"},inplace=True)

# %%
dfn.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 gpa  Placed
# 0     Joe        K   9.8  10.0   9.9  A+       1
# 1  Rajesh        M   8.9   9.1   9.3   A       1
# 2  Kissan        V   9.9   9.8  10.0   A       0
# 3    Mary        N   7.7   8.0   NaN   B       0
# 4    Jeen        K   9.8   9.1   9.9  A+       1

# %%
dfn['avg_score']=(dfn['SEM1']+dfn['SEM2']+dfn['SEM3'])/3

# %%
dfn.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 gpa  Placed  avg_score
# 0     Joe        K   9.8  10.0   9.9  A+       1        9.9
# 1  Rajesh        M   8.9   9.1   9.3   A       1        9.1
# 2  Kissan        V   9.9   9.8  10.0   A       0        9.9
# 3    Mary        N   7.7   8.0   NaN   B       0        NaN
# 4    Jeen        K   9.8   9.1   9.9  A+       1        9.6

# %%
dfn[['SEM1','SEM2']].plot.line()
# Out:
# <Axes: >

# %%
dfc2.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
import seaborn as sns

# %%
pl=sns.lineplot(x='Names',y='SEM1',data=dfc2)

# %%
sns.relplot(
    data=dfc2,
    x="SEM2",y="SEM1",col="Placed")

# %% [markdown]
#   load diabeties.scv
#   -

# %%
import pandas as pd

# %%
dfd=pd.read_csv("/content/diabetcsv.csv")
dfd
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
dfd['index']=range(1,2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-78e5e1fc4644> in <cell line: 1>()
# ----> 1 dfd['index']=range(1,2)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3978         else:
#    3979             # set column
# -> 3980             self._set_item(key, value)
#    3981
#    3982     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4172         ensure homogeneity.
#    4173         """
# -> 4174         value = self._sanitize_column(value)
#    4175
#    4176         if (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4913
#    4914         if is_list_like(value):
# -> 4915             com.require_length_match(value, self.index)
# ...

# %%
sns.relplot(
    data=dfd,
    x="index",y="age",col="class")

# %% [markdown]
# inbulit datasets in seaborn
# -tips
# -dowjones
# -fmri
# -dots
# -health exp
# to use datasets:
# load_dataset"(ds name")

# %%
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
dowjones=sns.load_dataset("dowjones")

# %%
fmri=sns.load_dataset("fmri")

# %%
dots=sns.load_dataset("dots")

# %%
healthexp=sns.load_dataset("healthexp")

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",col="time")

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",col="smoker")

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="time")

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="smoker")

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="size")

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",col="size")

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",col="day")

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="day",marker="*")

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="smoker",style="time")

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="smoker",style="day")

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="day",style="time")

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="day",style="size",palette="pastel")

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="size",style="day",palette="pastel")

# %% [markdown]
# pastel,bright,dark,muted,colorblind,deep palette

# %%
sns.relplot(
    data=tips,
    x="total_bill",y="tip",hue="day",style="time",kind="line")

# %%
dowjones
# Out:
#           Date   Price
# 0   1914-12-01   55.00
# 1   1915-01-01   56.55
# 2   1915-02-01   56.00
# 3   1915-03-01   58.30
# 4   1915-04-01   66.45
# ..         ...     ...
# 644 1968-08-01  883.72
# 645 1968-09-01  922.80
# 646 1968-10-01  955.47
# 647 1968-11-01  964.12
# 648 1968-12-01  965.39
#
# [649 rows x 2 columns]

# %%
sns.relplot(
    data=dowjones,
    x="Date",y="Price",kind="line")

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(
    data=fmri,
    x="signal",y="timepoint",col="region")

# %%
import seaborn as sns

# %%
sns.catplot(
    data=fmri,
    x="signal",y="timepoint")

# %%
sns.catplot(
    data=tips,
    x="total_bill",y="time",kind="violin",hue="smoker")

# %% [markdown]
# linerafit
# plotin the dataset
# fitting the line

# %%
sns.lmplot(x="size",y="tip",data=tips);

# %%
tips=sns.load_dataset("tips")

# %% [markdown]
# **webscrapping:**
# -loaring the data from the website
# -unstrucred in html
# -convertible into spreadsheet/DB
# -major website have their APIs for web scrapping
# **porpuse:**
# -extract the data on particular sites
# -specific data that a user wants
# **process:**
# -url
# -html code
# -elements(CSS/JS)
# -scrapes the required format(csv,xlsv,json)
# **application:**
# -emailmarketing
# -sentiment analysis
# -news monitoring
# -market research
# -price moinitoring
# **libraries:**
# -Beatufulsoup:scoups the HTML code
# -Requests-provides the acesses
# -selenium
# -pandas-
# -webdriver
# -webdriver_manager
# **to initial any library:**
# -!pip install library
# -!pip install--upgrade library#to upgrade to recent version
# import subpackage:
# from parent import child
# **beatufulsoup:**
# -used to scrape data from static website'
# -package bs4:subpackage beatufulsoup
# function       purpose                             attributes
# beatifulsoup() to extract html code from web page  text/html
# find()         to find first element of a kind     ('element-name')
# find_all()     to find all element of a kind       ('element-name')
# Requests
# -used to send request to web page
# -get('url')
